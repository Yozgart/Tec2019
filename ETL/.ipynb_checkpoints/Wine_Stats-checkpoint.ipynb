# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
pwd
# Out:
# '/Users/dianapardo/Documents/GitHub/Proyectos/First_MiniProject'

# %%
#First, get all information from de the dataset
Wds = ("./Liquor_Authority_Quarterly_List_of_Active_Licenses.csv")
wds_reg = pd.read_csv(Wds)
wds_reg
# Out:
#        License Serial Number                    License Type Name  \
# 0                    1000080                   GROCERY STORE BEER
# 1                    1000090                   GROCERY STORE BEER
# 2                    1000099                   GROCERY STORE BEER
# 3                    1000167                   GROCERY STORE BEER
# 4                    1000207                   GROCERY STORE BEER
# 5                    1000218                   GROCERY STORE BEER
# 6                    1000305                   GROCERY STORE BEER
# 7                    1000351                   GROCERY STORE BEER
# 8                    1000407                   GROCERY STORE BEER
# 9                    1000471              GROCERY BEER, WINE PROD
# 10                   1000482                   GROCERY STORE BEER
# 11                   1000542                   GROCERY STORE BEER
# 12                   1000552                   GROCERY STORE BEER
# ...

# %%
wds_reg.dtypes
# Out:
# License Serial Number                          int64
# License Type Name                             object
# License Class Code                           float64
# License Type Code                             object
# Agency Zone Office Name                       object
# Agency Zone Office Number                      int64
# County Name (Licensee)                        object
# Premises Name                                 object
# Doing Business As (DBA)                       object
# Actual Address of Premises (Address1)         object
# Additional Address Information (Address2)     object
# City                                          object
# State                                         object
# Zip                                           object
# License Certificate Number                     int64
# License Original Issue Date                   object
# License Effective Date                        object
# License Expiration Date                       object
# ...

# %%
print(wds_reg.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51235 entries, 0 to 51234
# Data columns (total 21 columns):
# License Serial Number                        51235 non-null int64
# License Type Name                            51235 non-null object
# License Class Code                           51189 non-null float64
# License Type Code                            51235 non-null object
# Agency Zone Office Name                      51235 non-null object
# Agency Zone Office Number                    51235 non-null int64
# County Name (Licensee)                       51235 non-null object
# Premises Name                                51235 non-null object
# Doing Business As (DBA)                      35795 non-null object
# Actual Address of Premises (Address1)        51235 non-null object
# Additional Address Information (Address2)    11154 non-null object
# City                                         51235 non-null object
# ...

# %%
wds_reg['License Type Name'].unique()
# Out:
# array(['GROCERY STORE BEER', 'GROCERY BEER, WINE PROD',
#        'EATING PLACE BEER', 'WHOLESALE CIDER', 'WHOLESALE BEER(C)',
#        'CLUB LIQUOR', 'WHOLESALE BEER(CO)', 'LIQUOR STORE',
#        'CATERING ESTABLISHMENT', 'DRUG CHAIN, WINE PROD',
#        'ON-PREMISES LIQUOR', 'RESTAURANT LIQUOR', 'RESTAURANT WINE',
#        'SUMMER EATING PLACE BEER', 'O.P. FOOD AND BEV',
#        'GROCERY CHAIN, WINE PROD', 'CIDER PRODUCER/WHOLESALER', 'BREWER',
#        'DRUG BEER, WINE PROD', 'HOTEL LIQUOR', 'WHOLESALE LIQUOR',
#        'WHOLESALE WINE', 'BALL PARK BEER', 'O.P. ENTERTAINMENT',
#        'SUMMER RESTAURANT LIQUOR', 'SUMMER CLUB LIQUOR',
#        'SUMMER VESSEL LIQUOR', 'TAVERN WINE', 'VESSEL LIQUOR',
#        'GROCERY CHAIN, BEER ONLY', 'CLUB BEER', 'WINERY', 'FARM WINERY',
#        'GOLF CLUB', 'MICRO BREWER', 'SUMMER O.P. FOOD & BEV',
#        'SUMMER GOLF CLUB', 'WINERY / FARM WINERY RETAIL',
#        'SUMMER CLUB BEER', 'AIRLINE COMPANY', 'WINE STORE',
# ...

# %%
wds_reg['Agency Zone Office Name'].unique()
# Out:
# array(['New York City', 'Albany', 'Buffalo'], dtype=object)

# %%
wds_reg['County Name (Licensee)'].unique()
# Out:
# array(['BRONX', 'ROCKLAND', 'KINGS', 'QUEENS', 'NEW YORK', 'RICHMOND',
#        'NASSAU', 'WESTCHESTER', 'SUFFOLK', 'ALBANY', 'ESSEX', 'CLINTON',
#        'COLUMBIA', 'DUTCHESS', 'FRANKLIN', 'FULTON', 'GREENE', 'HAMILTON',
#        'MONTGOMERY', 'ORANGE', 'PUTNAM', 'RENSSELAER', 'SARATOGA',
#        'SCHENECTADY', 'SCHOHARIE', 'SULLIVAN', 'ULSTER', 'WARREN',
#        'WASHINGTON', 'ONONDAGA', 'OTSEGO', 'JEFFERSON', 'HERKIMER',
#        'CORTLAND', 'CAYUGA', 'DELAWARE', 'ST LAWRENCE', 'LEWIS',
#        'ONTARIO', 'CHENANGO', 'MADISON', 'ONEIDA', 'BROOME', 'OSWEGO',
#        'ERIE', 'SENECA', 'ALLEGANY', 'CATTARAUGUS', 'CHAUTAUQUA',
#        'CHEMUNG', 'GENESEE', 'LIVINGSTON', 'MONROE', 'NIAGARA', 'ORLEANS',
#        'SCHUYLER', 'STEUBEN', 'TIOGA', 'TOMPKINS', 'WAYNE', 'WYOMING',
#        'YATES'], dtype=object)

# %%
nyds = ("./NYS_Liquor_Authority_New_Applications_Received.csv")
nysds_reg = pd.read_csv(nyds)
nysds_reg
# Out:
#       License Serial Number            License Type Name  License Class Code  \
# 0                   1302914           ON-PREMISES LIQUOR               252.0
# 1                   1304304           ON-PREMISES LIQUOR               252.0
# 2                   1304478              RESTAURANT WINE               341.0
# 3                   1306781           ON-PREMISES LIQUOR               252.0
# 4                   1308127      GROCERY BEER, WINE PROD               122.0
# 5                   1311598      GROCERY BEER, WINE PROD               122.0
# 6                   1312978      GROCERY BEER, WINE PROD               122.0
# 7                   1313065           ON-PREMISES LIQUOR               252.0
# 8                   1313103             WHOLESALE LIQUOR               203.0
# 9                   1313240      GROCERY BEER, WINE PROD               122.0
# 10                  1313257           ON-PREMISES LIQUOR               252.0
# ...

# %%
nysds_reg.dtypes
# Out:
# License Serial Number                          int64
# License Type Name                             object
# License Class Code                           float64
# License Type Code                             object
# Agency Zone Office Number                      int64
# Agency Zone Office Name                       object
# County Name (Licensee)                        object
# Premises Name                                 object
# Doing Business As (DBA)                       object
# Actual Address of Premises (Address1)         object
# Additional Address Information (Address2)     object
# City                                          object
# State                                         object
# ZIP                                            int64
# License Certificate Number                   float64
# License Received Date                         object
# dtype: object

# %%
print(nysds_reg.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1719 entries, 0 to 1718
# Data columns (total 16 columns):
# License Serial Number                        1719 non-null int64
# License Type Name                            1719 non-null object
# License Class Code                           1718 non-null float64
# License Type Code                            1719 non-null object
# Agency Zone Office Number                    1719 non-null int64
# Agency Zone Office Name                      1719 non-null object
# County Name (Licensee)                       1719 non-null object
# Premises Name                                1719 non-null object
# Doing Business As (DBA)                      999 non-null object
# Actual Address of Premises (Address1)        1719 non-null object
# Additional Address Information (Address2)    222 non-null object
# City                                         1719 non-null object
# State                                        1719 non-null object
# ...

# %% [markdown]
# License_original=[]
# License_effective=[]
# License_expiration=[]
# Latitude=[]
# Longitud=[]
# Location=[]
# nysds_reg['License Original Issue Date']=License_original
# nysds_reg['License Effective Date']=License_effective
# nysds_reg['License Expiration Date']=License_expiration
# nysds_reg['Latitude']=Latitude
# nysds_reg['Longitud']=Longitud
# nysds_reg['Location']=Location

# %%
merged=pd.merge(nysds_reg,wds_reg, how='outer')
merged
# Out:
#        License Serial Number                    License Type Name  \
# 0                    1302914                   ON-PREMISES LIQUOR
# 1                    1304304                   ON-PREMISES LIQUOR
# 2                    1304478                      RESTAURANT WINE
# 3                    1306781                   ON-PREMISES LIQUOR
# 4                    1308127              GROCERY BEER, WINE PROD
# 5                    1311598              GROCERY BEER, WINE PROD
# 6                    1312978              GROCERY BEER, WINE PROD
# 7                    1313065                   ON-PREMISES LIQUOR
# 8                    1313103                     WHOLESALE LIQUOR
# 9                    1313240              GROCERY BEER, WINE PROD
# 10                   1313257                   ON-PREMISES LIQUOR
# 11                   1313288                         LIQUOR STORE
# 12                   1313329              GROCERY BEER, WINE PROD
# ...

# %%
print(merged.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52909 entries, 0 to 52908
# Data columns (total 23 columns):
# License Serial Number                        52909 non-null int64
# License Type Name                            52909 non-null object
# License Class Code                           52862 non-null float64
# License Type Code                            52909 non-null object
# Agency Zone Office Number                    52909 non-null int64
# Agency Zone Office Name                      52909 non-null object
# County Name (Licensee)                       52909 non-null object
# Premises Name                                52909 non-null object
# Doing Business As (DBA)                      36763 non-null object
# Actual Address of Premises (Address1)        52909 non-null object
# Additional Address Information (Address2)    11369 non-null object
# City                                         52909 non-null object
# ...
