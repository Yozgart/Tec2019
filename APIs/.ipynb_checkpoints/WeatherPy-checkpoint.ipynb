# %%
# Load Dependecies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as owm
import datetime
now = datetime.datetime.now()
from api_keys import api_key
from citipy import citipy

output_data_file = "./Resources/cities.csv"

LatRange = (-90, 90)
LngRange = (-180, 180)

# %%
# Definition of Lat and Long
LatLngs = []
cities = []

# Random Lat & Long 
Lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
Lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
LatLngs = zip(Lats, Lngs)

# Neraby Cities based in Lat & Long 
for Lat_Lng in LatLngs:
    city = citipy.nearest_city(Lat_Lng[0], Lat_Lng[1]).city_name
    
    # Si la ciudad es unica, la agrega al listado de ciudades
    if city not in cities:
        cities.append(city)

# Print Cities 
len(cities)
# Out:
# 599

# %%
# API Conf
settings = {"units": "imperial", "appid": api_key}

# API Parameters 
params = ['name','clouds.all','sys.country','dt','main.humidity','main.temp','wind.speed']

# API Set
WeatherDf =pd.DataFrame(columns = ["City","Cloudiness", "Country", "Date", 
                                      "Humidity", "Lat","Lng", "Max Temp", 
                                      "Wind Speed"])

# %%
count = 1
error = 0 
sets = 0
index = 0

# Print legend at beginning
print("Beginning Data Retrieval    ")
print("----------------------------")

# Time of blocks
ts =time.time()

for city in cities:
    try:
        # Se re-emplazan los caracteres especiales.
        cityfix = city.replace(" ", "%20") 
        print(f'Processing Record {count} of Set {sets} | {cityfix}' )
        # print(f'{owm.BASE_URL}weather?q={cityfix}&units=imperial&APPID={api_key}')
        city_stats = owm.get_current(cityfix, **settings)
        WeatherDf.set_value(index, "City", city_stats["name"])
        WeatherDf.set_value(index, "Cloudiness", city_stats("clouds.all"))
        WeatherDf.set_value(index, "Country", city_stats("sys.country"))
        WeatherDf.set_value(index, "Date", city_stats("dt"))
        WeatherDf.set_value(index, "Humidity", city_stats("main.humidity"))
        WeatherDf.set_value(index, "Lat", city_stats("coord.lat"))
        WeatherDf.set_value(index, "Lng", city_stats("coord.lon"))
        WeatherDf.set_value(index, "Max Temp", city_stats("main.temp_max"))
        WeatherDf.set_value(index, "Wind Speed", city_stats("wind.speed"))
        index = index + 1 
    except Exception as e:
        print("City not found. Skipping...")
        error = error + 1
        
    count = count + 1
    # Timeout validation
    if count == 51: 
        count = 1 
        sets = sets+1

# Print legend at the end
print("----------------------------")
print("Data Retrieval Complete     ")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 0 | castro
# C:\Users\yozga\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yozga\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yozga\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yozga\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yozga\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yozga\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yozga\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yozga\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yozga\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:30: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing Record 2 of Set 0 | hithadhoo
# Processing Record 3 of Set 0 | punta%20arenas
# City not found. Skipping...
# Processing Record 4 of Set 0 | rikitea
# Processing Record 5 of Set 0 | bredasdorp
# Processing Record 6 of Set 0 | xifeng
# Processing Record 7 of Set 0 | pangnirtung
# Processing Record 8 of Set 0 | bluff
# Processing Record 9 of Set 0 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 0 | tuktoyaktuk
# Processing Record 11 of Set 0 | ye
# City not found. Skipping...
# Processing Record 12 of Set 0 | new%20norfolk
# City not found. Skipping...
# Processing Record 13 of Set 0 | bengkulu
# City not found. Skipping...
# Processing Record 14 of Set 0 | padang
# Processing Record 15 of Set 0 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 0 | petrolandia
# City not found. Skipping...
# Processing Record 17 of Set 0 | avarua
# Processing Record 18 of Set 0 | buraydah
# Processing Record 19 of Set 0 | hermanus
# Processing Record 20 of Set 0 | victoria
# Processing Record 21 of Set 0 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 0 | aquiraz
# Processing Record 23 of Set 0 | klaksvik
# Processing Record 24 of Set 0 | nizwa
# Processing Record 25 of Set 0 | hobart
# Processing Record 26 of Set 0 | airai
# Processing Record 27 of Set 0 | lasa
# Processing Record 28 of Set 0 | hervey%20bay
# City not found. Skipping...
# Processing Record 29 of Set 0 | atuona
# Processing Record 30 of Set 0 | komsomolskiy
# Processing Record 31 of Set 0 | nanortalik
# Processing Record 32 of Set 0 | thompson
# Processing Record 33 of Set 0 | cabo%20san%20lucas
# City not found. Skipping...
# Processing Record 34 of Set 0 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 0 | pisco
# Processing Record 36 of Set 0 | chanthaburi
# Processing Record 37 of Set 0 | kandrian
# Processing Record 38 of Set 0 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 0 | bambous%20virieux
# City not found. Skipping...
# Processing Record 40 of Set 0 | puerto%20ayora
# City not found. Skipping...
# Processing Record 41 of Set 0 | belushya%20guba
# City not found. Skipping...
# Processing Record 42 of Set 0 | cheremshan
# Processing Record 43 of Set 0 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 0 | khatanga
# Processing Record 45 of Set 0 | port%20elizabeth
# City not found. Skipping...
# Processing Record 46 of Set 0 | kahului
# Processing Record 47 of Set 0 | kapaa
# Processing Record 48 of Set 0 | chokurdakh
# Processing Record 49 of Set 0 | kavieng
# Processing Record 50 of Set 0 | norman%20wells
# City not found. Skipping...
# Processing Record 1 of Set 1 | taoudenni
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | pokaran
# Processing Record 4 of Set 1 | ebeltoft
# Processing Record 5 of Set 1 | wolbrom
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | santa%20rosa
# City not found. Skipping...
# Processing Record 8 of Set 1 | mahebourg
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | sterling
# Processing Record 11 of Set 1 | sept-iles
# Processing Record 12 of Set 1 | fairbanks
# Processing Record 13 of Set 1 | cape%20town
# City not found. Skipping...
# Processing Record 14 of Set 1 | auki
# Processing Record 15 of Set 1 | gimbi
# Processing Record 16 of Set 1 | henties%20bay
# City not found. Skipping...
# Processing Record 17 of Set 1 | saint%20george
# City not found. Skipping...
# Processing Record 18 of Set 1 | cap-aux-meules
# Processing Record 19 of Set 1 | farmington
# Processing Record 20 of Set 1 | axim
# Processing Record 21 of Set 1 | touros
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | egvekinot
# Processing Record 25 of Set 1 | huejucar
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | fortuna
# Processing Record 28 of Set 1 | butaritari
# Processing Record 29 of Set 1 | ocher
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | freeport
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | mastic%20beach
# City not found. Skipping...
# Processing Record 36 of Set 1 | semirom
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | sukhumi
# City not found. Skipping...
# Processing Record 39 of Set 1 | flin%20flon
# City not found. Skipping...
# Processing Record 40 of Set 1 | saskylakh
# Processing Record 41 of Set 1 | puerto%20baquerizo%20moreno
# City not found. Skipping...
# Processing Record 42 of Set 1 | benalla
# Processing Record 43 of Set 1 | ballina
# Processing Record 44 of Set 1 | ribeira%20grande
# City not found. Skipping...
# Processing Record 45 of Set 1 | terrace
# Processing Record 46 of Set 1 | yichang
# Processing Record 47 of Set 1 | berlevag
# Processing Record 48 of Set 1 | cayenne
# Processing Record 49 of Set 1 | cherskiy
# Processing Record 50 of Set 1 | longyearbyen
# Processing Record 1 of Set 2 
of Set 3 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 3 | bojnurd
# Processing Record 20 of Set 3 | esperance
# Processing Record 21 of Set 3 | coquimbo
# Processing Record 22 of Set 3 | moissala
# Processing Record 23 of Set 3 | otjiwarongo
# Processing Record 24 of Set 3 | ilulissat
# Processing Record 25 of Set 3 | bethel
# Processing Record 26 of Set 3 | yumen
# Processing Record 27 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 3 | kirkuk
# Processing Record 29 of Set 3 | khandyga
# Processing Record 30 of Set 3 | souillac
# Processing Record 31 of Set 3 | vila%20velha
# City not found. Skipping...
# Processing Record 32 of Set 3 | lavrentiya
# Processing Record 33 of Set 3 | laurel
# Processing Record 34 of Set 3 | sao%20filipe
# City not found. Skipping...
# Processing Record 35 of Set 3 | beringovskiy
# Processing Record 36 of Set 3 | port%20macquarie
# City not found. Skipping...
# Processing Record 37 of Set 3 | jiexiu
# Processing Record 38 of Set 3 | cooma
# Processing Record 39 of Set 3 | yoichi
# Processing Record 40 of Set 3 | torbay
# Processing Record 41 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 3 | bilibino
# Processing Record 43 of Set 3 | sabzevar
# Processing Record 44 of Set 3 | rio%20gallegos
# City not found. Skipping...
# Processing Record 45 of Set 3 | qaqortoq
# Processing Record 46 of Set 3 | maryborough
# Processing Record 47 of Set 3 | jamestown
# Processing Record 48 of Set 3 | ziyang
# Processing Record 49 of Set 3 | shimoda
# Processing Record 50 of Set 3 | kodiak
# Processing Record 1 of Set 4 | vila
# Processing Record 2 of Set 4 | ha%20tinh
# City not found. Skipping...
# Processing Record 3 of Set 4 | nikolskoye
# Processing Record 4 of Set 4 | itaueira
# Processing Record 5 of Set 4 | okhotsk
# Processing Record 6 of Set 4 | luderitz
# Processing Record 7 of Set 4 | serowe
# Processing Record 8 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 4 | alofi
# Processing Record 10 of Set 4 | zhigansk
# Processing Record 11 of Set 4 | sisimiut
# Processing Record 12 of Set 4 | aleksandrovsk-sakhalinskiy
# Processing Record 13 of Set 4 | kruisfontein
# Processing Record 14 of Set 4 | hami
# Processing Record 15 of Set 4 | sindor
# Processing Record 16 of Set 4 | sawtell
# Processing Record 17 of Set 4 | wadi%20musa
# City not found. Skipping...
# Processing Record 18 of Set 4 | severo-kurilsk
# Processing Record 19 of Set 4 | ajdabiya
# Processing Record 20 of Set 4 | kuybysheve
# Processing Record 21 of Set 4 | bam
# Processing Record 22 of Set 4 | carnarvon
# Processing Record 23 of Set 4 | lumphat
# Processing Record 24 of Set 4 | college
# Processing Record 25 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 4 | mbengwi
# Processing Record 27 of Set 4 | ust-ishim
# Processing Record 28 of Set 4 | aklavik
# Processing Record 29 of Set 4 | juneau
# Processing Record 30 of Set 4 | ternitz
# Processing Record 31 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 4 | marrakesh
# Processing Record 33 of Set 4 | plouzane
# Processing Record 34 of Set 4 | skovorodino
# Processing Record 35 of Set 4 | ruidoso
# Processing Record 36 of Set 4 | whitehorse
# Processing Record 37 of Set 4 | manoharpur
# Processing Record 38 of Set 4 | nabire
# Processing Record 39 of Set 4 | lompoc
# Processing Record 40 of Set 4 | caravelas
# Processing Record 41 of Set 4 | nelson%20bay
# City not found. Skipping...
# Processing Record 42 of Set 4 | nishihara
# Processing Record 43 of Set 4 | gujan-mestras
# Processing Record 44 of Set 4 | upernavik
# Processing Record 45 of Set 4 | fort%20saint%20john
# City not found. Skipping...
# Processing Record 46 of Set 4 | lebu
# Processing Record 47 of Set 4 | yar-sale
# Processing Record 48 of Set 4 | vostok
# Processing Record 49 of Set 4 | yarega
# Processing Record 50 of Set 4 | hofn
# Processing Record 1 of Set 5 | grand%20gaube
# City not found. Skipping...
# Processing Record 2 of Set 5 | kaeo
# Processing Record 3 of Set 5 | sarny
# Processing Record 4 of Set 5 | ventnor%20city
# City not found. Skipping...
# Processing Record 5 of Set 5 | zyryanka
# Processing Record 6 of Set 5 | juegang
# Processing Record 7 of Set 5 | itoman
# Processing Record 8 of Set 5 | port%20lincoln
# City not found. Skipping...
# Processing Record 9 of Set 5 | saint-joseph
# Processing Record 10 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 11 of Set 5 | isla%20vista
# City not found. Skipping...
# Processing Record 12 of Set 5 | higuey
# City not found. Skipping...
# Processing Record 13 of Set 5 | tautira
# Processing Record 14 of Set 5 | lerwick
# Processing Record 15 of Set 5 | pangody
# Processing Record 16 of Set 5 | bridlington
# Processing Record 17 of Set 5 | katsuura
# Processing Record 18 of Set 5 | providencia
# Processing Record 19 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 5 | paamiut
# Processing Record 21 of Set 5 | picota
# Processing Record 22 of Set 5 | grand%20river%20south%20east
# City not found. Skipping...
# Processing Record 23 of Set 5 | kita
# Processing Record 24 of Set 5 | masty
# Processing Record 25 of Set 5 | kuytun
# Processing Record 26 of Set 5 | camana
# City not found. Skipping...
# Processing Record 27 of Set 5 | ust-maya
# Processing Record 28 of Set 5 | mehamn
# Processing Record 29 of Set 5 | oranjestad
# Processing Record 30 of Set 5 | acapulco
# Processing Record 31 of Set 5 | phan%20thiet
# City not found. Skipping...
# Processing Record 32 of Set 5 | antofagasta
# Processing Record 33 of Set 5 | la%20tuque
# City not found. Skipping...
# Processing Record 34 of Set 5 | poronaysk
# Processing Record 35 of Set 5 | wajima
# Processing Record 36 of Set 5 | madang
# Processing Record 37 of Set 5 | tura
# Processing Record 38 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 39 of Set 5 | ponta%20do%20sol
# City not found. Skipping...
# Processing Record 40 of Set 5 | hamilton
# Processing Record 41 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 42 of Set 5 | nouadhibou
# Processing Record 43 of Set 5 | hirara
# Processing Record 44 of Set 5 | gold%20coast
# City not found. Skipping...
# Processing Record 45 of Set 5 | puerto%20ayacucho
# City not found. Skipping...
# Processing Record 46 of Set 5 | presov
# Processing Record 47 of Set 5 | rawson
# Processing Record 48 of Set 5 | wakkanai
# Processing Record 49 of Set 5 | oistins
# Processing Record 50 of Set 5 | atar
# Processing Record 1 of Set 6 | chalus
# Processing Record 2 of Set 6 | hede
# Processing Record 3 of Set 6 | atbasar
# Processing Record 4 of Set 6 | trincomalee
# Processing Record 5 of Set 6 | banswada
# Processing Record 6 of Set 6 | matara
# Processing Record 7 of Set 6 | torre%20santa%20susanna
# City not found. Skipping...
# Processing Record 8 of Set 6 | havoysund
# Processing Record 9 of Set 6 | vao
# Processing Record 10 of Set 6 | biak
# Processing Record 11 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 12 of Set 6 | port-gentil
# Processing Record 13 of Set 6 | coahuayana
# Processing Record 14 of Set 6 | mackay
# Processing Record 15 of Set 6 | saint-francois
# Processing Record 16 of Set 6 | havre
# Processing Record 17 of Set 6 | lagoa
# Processing Record 18 of Set 6 | vyartsilya
# Processing Record 19 of Set 6 | show%20low
# City not found. Skipping...
# Processing Record 20 of Set 6 | santa%20ana
# City not found. Skipping...
# Processing Record 21 of Set 6 | portland
# Processing Record 22 of Set 6 | constitucion
# Processing Record 23 of Set 6 | harper
# Processing Record 24 of Set 6 | lubango
# Processing Record 25 of Set 6 | muros
# Processing Record 26 of Set 6 | leshan
# City not found. Skipping...
# Processing Record 27 of Set 6 | gigant
# Processing Record 28 of Set 6 | sarakhs
# Processing Record 29 of Set 6 | kunnamangalam
# Processing Record 30 of Set 6 | kolpashevo
# Processing Record 31 of Set 6 | pauini
# Processing Record 32 of Set 6 | huarmey
# Processing Record 33 of Set 6 | shiloh
# Processing Record 34 of Set 6 | kovur
# Processing Record 35 of Set 6 | lukovetskiy
# Processing Record 36 of Set 6 | matay
# Processing Record 37 of Set 6 | pevek
# Processing Record 38 of Set 6 | graham
# Processing Record 39 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 6 | alyangula
# Processing Record 41 of Set 6 | khandbari
# Processing Record 42 of Set 6 | dourbali
# Processing Record 43 of Set 6 | warwick
# Processing Record 44 of Set 6 | tilichiki
# Processing Record 45 of Set 6 | longview
# Processing Record 46 of Set 6 | dodoma
# Processing Record 47 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 48 of Set 6 | krasnoselkup
# City not found. Skipping...
# Processing Record 49 of Set 6 | kupino
# Processing Record 50 of Set 6 | omsukchan
# Processing Record 1 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 7 | saint-augustin
# Processing Record 3 of Set 7 | guerrero%20negro
# City not found. Skipping...
# Processing Record 4 of Set 7 | hasaki
# Processing Record 5 of Set 7 | fort%20portal
# City not found. Skipping...
# Processing Record 6 of Set 7 | gorgan
# Processing Record 7 of Set 7 | alice%20springs
# City not found. Skipping...
# Processing Record 8 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 7 | lardos
# Processing Record 10 of Set 7 | great%20bend
# City not found. Skipping...
# Processing Record 11 of Set 7 | porto%20novo
# City not found. Skipping...
# Processing Record 12 of Set 7 | pritzwalk
# Processing Record 13 of Set 7 | ilo
# Processing Record 14 of Set 7 | cajamarca
# Processing Record 15 of Set 7 | ngorongoro
# Processing Record 16 of Set 7 | davila
# Processing Record 17 of Set 7 | himora
# City not found. Skipping...
# Processing Record 18 of Set 7 | igarka
# Processing Record 19 of Set 7 | veraval
# Processing Record 20 of Set 7 | nantucket
# Processing Record 21 of Set 7 | requena
# Processing Record 22 of Set 7 | saldanha
# Processing Record 23 of Set 7 | asau
# City not found. Skipping...
# Processing Record 24 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 25 of Set 7 | udaipur
# Processing Record 26 of Set 7 | pamplona
# Processing Record 27 of Set 7 | sesheke
# Processing Record 28 of Set 7 | araouane
# Processing Record 29 of Set 7 | sao%20joao%20da%20barra
# City not found. Skipping...
# Processing Record 30 of Set 7 | zeya
# Processing Record 31 of Set 7 | evensk
# Processing Record 32 of Set 7 | lazaro%20cardenas
# City not found. Skipping...
# Processing Record 33 of Set 7 | boca%20do%20acre
# City not found. Skipping...
# Processing Record 34 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 35 of Set
# Processing Record 4 of Set 9 | tarquinia
# Processing Record 5 of Set 9 | bhander
# Processing Record 6 of Set 9 | ixtapa
# Processing Record 7 of Set 9 | copiague
# Processing Record 8 of Set 9 | zalantun
# Processing Record 9 of Set 9 | chuy
# Processing Record 10 of Set 9 | comodoro%20rivadavia
# City not found. Skipping...
# Processing Record 11 of Set 9 | mount%20gambier
# City not found. Skipping...
# Processing Record 12 of Set 9 | naze
# Processing Record 13 of Set 9 | bosaso
# Processing Record 14 of Set 9 | cacu
# Processing Record 15 of Set 9 | oussouye
# Processing Record 16 of Set 9 | roald
# Processing Record 17 of Set 9 | dukat
# Processing Record 18 of Set 9 | kavaratti
# Processing Record 19 of Set 9 | huilong
# Processing Record 20 of Set 9 | burica
# City not found. Skipping...
# Processing Record 21 of Set 9 | guanica
# Processing Record 22 of Set 9 | adre
# Processing Record 23 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 9 | honiara
# Processing Record 25 of Set 9 | lakes%20entrance
# City not found. Skipping...
# Processing Record 26 of Set 9 | makung
# City not found. Skipping...
# Processing Record 27 of Set 9 | mogadishu
# Processing Record 28 of Set 9 | saint-leu
# Processing Record 29 of Set 9 | taltal
# Processing Record 30 of Set 9 | chapais
# Processing Record 31 of Set 9 | ostrovnoy
# Processing Record 32 of Set 9 | nioaque
# Processing Record 33 of Set 9 | swan%20hill
# City not found. Skipping...
# Processing Record 34 of Set 9 | trinidad
# Processing Record 35 of Set 9 | lubbenau
# Processing Record 36 of Set 9 | camopi
# Processing Record 37 of Set 9 | dingle
# Processing Record 38 of Set 9 | praia%20da%20vitoria
# City not found. Skipping...
# Processing Record 39 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 9 | bratsk
# Processing Record 41 of Set 9 | kunya
# Processing Record 42 of Set 9 | biryusinsk
# Processing Record 43 of Set 9 | abha
# Processing Record 44 of Set 9 | godda
# Processing Record 45 of Set 9 | eruwa
# Processing Record 46 of Set 9 | goundam
# Processing Record 47 of Set 9 | mizpe%20ramon
# City not found. Skipping...
# Processing Record 48 of Set 9 | port%20blair
# City not found. Skipping...
# Processing Record 49 of Set 9 | bay%20roberts
# City not found. Skipping...
# Processing Record 50 of Set 9 | miri
# Processing Record 1 of Set 10 | maceio
# Processing Record 2 of Set 10 | belaya%20gora
# City not found. Skipping...
# Processing Record 3 of Set 10 | port%20hardy
# City not found. Skipping...
# Processing Record 4 of Set 10 | belmonte
# Processing Record 5 of Set 10 | sharjah
# Processing Record 6 of Set 10 | tiznit
# Processing Record 7 of Set 10 | hualmay
# Processing Record 8 of Set 10 | san%20patricio
# City not found. Skipping...
# Processing Record 9 of Set 10 | ciudad%20bolivar
# City not found. Skipping...
# Processing Record 10 of Set 10 | andra
# Processing Record 11 of Set 10 | cape%20coast
# City not found. Skipping...
# Processing Record 12 of Set 10 | emerald
# Processing Record 13 of Set 10 | canutama
# Processing Record 14 of Set 10 | muriti
# Processing Record 15 of Set 10 | macedo%20de%20cavaleiros
# City not found. Skipping...
# Processing Record 16 of Set 10 | verkhovazhye
# Processing Record 17 of Set 10 | mitsamiouli
# Processing Record 18 of Set 10 | villa%20maria
# City not found. Skipping...
# Processing Record 19 of Set 10 | balkanabat
# Processing Record 20 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 21 of Set 10 | satun
# Processing Record 22 of Set 10 | nemuro
# Processing Record 23 of Set 10 | acajutla
# Processing Record 24 of Set 10 | bellevue
# Processing Record 25 of Set 10 | bara
# Processing Record 26 of Set 10 | maningrida
# Processing Record 27 of Set 10 | itagiba
# Processing Record 28 of Set 10 | phanat%20nikhom
# City not found. Skipping...
# Processing Record 29 of Set 10 | alenquer
# Processing Record 30 of Set 10 | ahipara
# Processing Record 31 of Set 10 | yulara
# Processing Record 32 of Set 10 | pandan
# Processing Record 33 of Set 10 | qandala
# Processing Record 34 of Set 10 | porto%20murtinho
# City not found. Skipping...
# Processing Record 35 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 37 of Set 10 | bonthe
# Processing Record 38 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 10 | bardiyah
# City not found. Skipping...
# Processing Record 40 of Set 10 | teguise
# Processing Record 41 of Set 10 | anloga
# Processing Record 42 of Set 10 | wanning
# Processing Record 43 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 44 of Set 10 | launceston
# Processing Record 45 of Set 10 | vitina
# Processing Record 46 of Set 10 | sao%20lourenco%20do%20sul
# City not found. Skipping...
# Processing Record 47 of Set 10 | sooke
# Processing Record 48 of Set 10 | boende
# Processing Record 49 of Set 10 | santa%20marinella
# City not found. Skipping...
# Processing Record 50 of Set 10 | cap%20malheureux
# City not found. Skipping...
# Processing Record 1 of Set 11 | sitka
# Processing Record 2 of Set 11 | likasi
# Processing Record 3 of Set 11 | grande%20prairie
# City not found. Skipping...
# Processing Record 4 of Set 11 | ust-kan
# Processing Record 5 of Set 11 | dunedin
# Processing Record 6 of Set 11 | aktau
# Processing Record 7 of Set 11 | abu%20zabad
# City not found. Skipping...
# Processing Record 8 of Set 11 | manokwari
# Processing Record 9 of Set 11 | gaoua
# Processing Record 10 of Set 11 | chachapoyas
# Processing Record 11 of Set 11 | tomatlan
# Processing Record 12 of Set 11 | dien%20bien
# City not found. Skipping...
# Processing Record 13 of Set 11 | lata
# Processing Record 14 of Set 11 | ketchikan
# Processing Record 15 of Set 11 | broken%20hill
# City not found. Skipping...
# Processing Record 16 of Set 11 | puteyets
# Processing Record 17 of Set 11 | rorvik
# Processing Record 18 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 11 | mataram
# Processing Record 20 of Set 11 | virginia%20beach
# City not found. Skipping...
# Processing Record 21 of Set 11 | korla
# City not found. Skipping...
# Processing Record 22 of Set 11 | dawson%20creek
# City not found. Skipping...
# Processing Record 23 of Set 11 | ust-omchug
# Processing Record 24 of Set 11 | ilave
# Processing Record 25 of Set 11 | anadyr
# Processing Record 26 of Set 11 | mandalgovi
# Processing Record 27 of Set 11 | san%20vicente
# City not found. Skipping...
# Processing Record 28 of Set 11 | phumi%20samraong
# City not found. Skipping...
# Processing Record 29 of Set 11 | hearst
# Processing Record 30 of Set 11 | temecula
# Processing Record 31 of Set 11 | robertsport
# Processing Record 32 of Set 11 | levelland
# Processing Record 33 of Set 11 | kamenka
# Processing Record 34 of Set 11 | bousso
# City not found. Skipping...
# Processing Record 35 of Set 11 | banda%20aceh
# City not found. Skipping...
# Processing Record 36 of Set 11 | broome
# Processing Record 37 of Set 11 | puerto%20leguizamo
# City not found. Skipping...
# Processing Record 38 of Set 11 | camacha
# Processing Record 39 of Set 11 | macusani
# Processing Record 40 of Set 11 | faya
# Processing Record 41 of Set 11 | cidreira
# Processing Record 42 of Set 11 | samarai
# Processing Record 43 of Set 11 | harihar
# Processing Record 44 of Set 11 | port%20hawkesbury
# City not found. Skipping...
# Processing Record 45 of Set 11 | babanka
# Processing Record 46 of Set 11 | neustadt
# Processing Record 47 of Set 11 | laguna
# Processing Record 48 of Set 11 | dicabisagan
# Processing Record 49 of Set 11 | coos%20bay
# City not found. Skipping...
# ----------------------------
# Data Retrieval Complete

# %%
WeatherDf.count()
# Out:
# City          431
# Cloudiness    431
# Country       431
# Date          431
# Humidity      431
# Lat           431
# Lng           431
# Max Temp      431
# Wind Speed    431
# dtype: int64

# %%
WeatherDf.to_csv("WeatherPy.csv", encoding='utf-8', index=False)
WeatherDf.head()
# Out:
#          City Cloudiness Country        Date Humidity    Lat     Lng Max Temp  \
# 0      Castro         88      CL  1554181200      100 -42.48  -73.76     48.2
# 1   Hithadhoo         32      MV  1554186337      100   -0.6   73.08    83.69
# 2     Rikitea          0      PF  1554186338      100 -23.12 -134.97    75.95
# 3  Bredasdorp         44      ZA  1554185802       81 -34.53   20.04       59
# 4      Xifeng         44      CN  1554186339       46  42.73  124.72    43.46
#
#   Wind Speed
# 0       1.12
# 1       9.01
# 2      16.84
# 3          4
# 4       8.46

# %%
# Creating a function to set the properties of the graph
def plotprops(xlabelname,ylabelname,xlimits):
    plt.xlabel(xlabelname)
    plt.ylabel(ylabelname)
    plt.xlim(xlimits)
    plt.title("%s vs %s (%s/%s/%s)"%(xlabelname,ylabelname,now.month,now.day,now.year),fontsize=14)
    plt.grid(True)

# %%
# Latitude Graph
plt.scatter(WeatherDf["Lat"], WeatherDf["Max Temp"], marker="o", facecolors="LightBlue", edgecolors="black")
plotprops("Latitude","Max. Temperature(°F)",[-90,90])
plt.savefig("LatitudVsTemperature.png")
plt.show()

# %%
# Humidity Graph
plt.scatter(WeatherDf["Lat"], WeatherDf["Humidity"], marker="o", facecolors="LightBlue", edgecolors="black")
plotprops("Latitude","Humidity (%)",[-90,90])
plt.savefig("LatitudVsTemperature.png")
plt.show()

# %%
# Cloudiness Graph
plt.scatter(WeatherDf["Lat"], WeatherDf["Cloudiness"], marker="o", facecolors="LightBlue", edgecolors="black")
plotprops("Latitude","Cloudiness(%)",[-90,90])
plt.savefig("LatitudevsCloudiness.png")
plt.show()

# %%
# Wind speed Graph
plt.scatter(WeatherDf["Lat"], WeatherDf["Wind Speed"], marker="o", facecolors="LightBlue", edgecolors="black")
plotprops("Latitude","Cloudiness(%)",[-90,90])
plt.savefig("LatitudevsWind.png")
plt.show()
